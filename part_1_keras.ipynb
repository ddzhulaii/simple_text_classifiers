# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

import nltk
import string
import numpy as np
import pandas as pd
from nltk.corpus import stopwords

from sklearn.manifold import TSNE

import re
import string
from nltk.stem.snowball import *
# Out:
# C:\Users\ODARKA\Anaconda2\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Part 1

# %% [markdown]
# ##### ---> building a neural network with LSTM and word embeddings were leaned while fitting the neural network on the classification problem

# %%
df = pd.read_csv('new_yelp.csv', index_col=0, low_memory=False)

# %%
df.head()
# Out:
#                       review_id                 user_id  \
# 3343256  zthVOctc7sTONdtEjoi6Vg  tqxTc21Df_qLSmSbZk447g
# 3160600  tmOC1c0laXLdTwRk7Ik3lg  qszR--MaJ_qWUt-laMXFBw
# 2541439  cN444GYzJd7k52x8xUHzUw  rt3PC7WCgCKsoufmQJELfw
# 3356848  5w3kt0iaS5ifweyE0sYFhw  XlgzY-TioqNy--pxPBoH4Q
# 1215656  3ZkPcaRfX3jp7IRgtmwlqg  oN4Dq_aZuOkapFgjrVVK_w
#
#                     business_id  stars        date  \
# 3343256  59OgPGGzKFYqwSG_U06kuA      5  2015-03-23
# 3160600  U4OLUFb9VxMmpMXm1ZF-cQ      4  2012-05-08
# 2541439  g8OnV26ywJlZpezdBnOWUQ      4  2009-09-10
# 3356848  5DDumAHRKumv3gZiPKW6iw      5  2012-05-20
# 1215656  EgRpbUZKPiotTXdrOM06VA      4  2012-09-23
#
#                                                       text  useful  funny  \
# 3343256  This is my favorite Korean restaurant in Arizo...     3.0    0.0
# 3160600  I come in here every week for some delicious c...     0.0    0.0
# 2541439  We joined our out-of-town guests for breakfast...    11.0    5.0
# 3356848  First of all, the people who work here are gre...     0.0    0.0
# 1215656  What a fantastic find! We came here based on t...     0.0    0.0
#
#          cool  labels
# 3343256   0.0     1.0
# 3160600   0.0     1.0
# 2541439   8.0     1.0
# 3356848   2.0     1.0
# 1215656   0.0     1.0

# %%
df = df[~df.isna().any(axis=1)]

# %%
def clean_text(text):
    text = text.translate(string.punctuation)
    text = text.lower().split()
    stops = set(stopwords.words('english'))
    text = [word for word in text if (word not in stops) & (len(word) > 3)]
    text = ' '.join(text)
    
    #Cleaning
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)    
    
    #Stemming
    text = text.split()
    stemmer = SnowballStemmer('english')
    stemmed_words = [stemmer.stem(word) for word in text]
    text = ' '.join(stemmed_words)
    
    return text

# %%
df['text'] = df['text'].apply(lambda x: clean_text(x))

# %%
voc_size = 20000
tokenizer = Tokenizer(num_words=voc_size)
tokenizer.fit_on_texts(df['text'])

seqs = tokenizer.texts_to_sequences(df['text'])
data = pad_sequences(seqs, maxlen=50)

# %%
# %%time
model = Sequential()
model.add(Embedding(voc_size, 100, input_length=50))
model.add(LSTM(100, dropout=.2, recurrent_dropout=.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', 
              metrics=['accuracy'])
model.fit(data, df['labels'], validation_split=0.4, epochs=3)
# Out:
# Train on 1041810 samples, validate on 694540 samples
# Epoch 1/3
# 1041810/1041810 [==============================] - 3509s 3ms/step - loss: 0.2748 - acc: 0.8830 - val_loss: 0.2545 - val_acc: 0.8929
# Epoch 2/3
# 1041810/1041810 [==============================] - 3534s 3ms/step - loss: 0.2390 - acc: 0.8996 - val_loss: 0.2448 - val_acc: 0.8966
# Epoch 3/3
# 1041810/1041810 [==============================] - 3479s 3ms/step - loss: 0.2237 - acc: 0.9071 - val_loss: 0.2428 - val_acc: 0.8991
# Wall time: 2h 55min 24s

# %%
word_embs = model.layers[0].get_weights()[0]

# %%
X_embedded = TSNE(n_components=2, random_state=42).fit_transform(word_embs)

# %%
word_list = []
for word, i in tokenizer.word_index.items():
    word_list.append(word)

# %%
number_of_words = 1000
trace = go.Scatter(
    x=X_embedded[0:number_of_words,0], 
    y=X_embedded[0:number_of_words, 1],
    mode='markers',
    text=word_list[0:number_of_words]
)
layout = dict(title='t-SNE 1 vs t-SNE 2 for first 1000 words ',
              yaxis=dict(title='t-SNE 2'),
              xaxis=dict(title='t-SNE 1'),
              hovermode='closest')
fig = dict(data=[trace], layout=layout)
py.iplot(fig)
# Out:
# <div id="f0e253aa-9ea8-40ea-b6af-c6540422f877" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f0e253aa-9ea8-40ea-b6af-c6540422f877", [{"type": "scatter", "text": ["falafelli", "cpc", "esigenza", "uggggghhhhhhh", "chersterland", "wochenkart", "olujimi", "pcos", "pfitzer", "confrenc", "2ae8v6a", "nonveggi", "suborn", "hiltz", "nagt", "sander", "tissur", "cocktal", "oliveri", "jiega", "5w4daoys28o", "wirlpool", "unempow", "sardischen", "iwer", "repl", "66long", "trye", "boucher", "ayna", "horolago", "remarquon", "februrari", "looney", "citus", "doeznt", "jolla", "visitin", "rovebrand", "ausspucken", "mecan", "visibili", "chalki", "extravaganza", "wemar", "daherkommt", "vyle", "fritomlet", "overattent", "postwar", "finiah", "5pi4", "genef", "wuick", "geekiest", "unconcern", "cerisesm", "mexio", "obstbuffet", "sk4h1rkqtlrcfbkx36ldsw", "oranges", "arkoun", "silvermin", "extraaaa", "keel", "ahlert", "urlaub", "bezogenen", "grunnet", "ficus", "gondola", "schwabian", "rdiga", "evwryon", "2post", "scarpariello", "ghac", "jillet", "taryn", "gehofft", "carsoul", "hatfiel", "sandy", "schitnzel", "coffe", "polari", "nodeal", "annalis", "named", "kepner", "hhgreg", "brewhaus", "eldelflow", "courtenay", "puttonyo", "szecguan", "7t5tif3000t8slqjl5b7uhca", "36mo", "sita", "overexpos", "plomero", "24ish", "grep", "horribleee", "zanacki", "brightth", "250000", "pelot", "highjack", "fizzmagillicutti", "chompi", "minutw", "drunken", "longhorn", "ckspreis", "tech2learn", "daytona", "worksheet", "salarymen", "aneth", "fitness", "manejar", "soondubi", "luftlini", "tychell", "craisin", "geschmacksneutralem", "brillinat", "restaurantatmosp", "rezensionen", "investiert", "cose", "hollendais", "worrh", "harv", "pakzad", "kareoke", "p1xmj0", "pullizt", "seizz", "nazna", "rappelait", "srimp", "bargainmov", "osar", "shutllebus", "daugher", "homeboy", "quantiri", "confsu", "ltimo", "reservu", "pacbel", "downsrair", "fukuburg", "manouri", "djovyxuldozlg", "gbh", "mcmenu", "massaro", "kadeena", "quieux", "001cc4c002e0", "toptabl", "animatronix", "beschwerdemanag", "connosseir", "hahahshaha", "iberica", "refrig", "wangatang", "pillowli", "hlchen", "jasonsdelilv", "mp3", "techlunchnorth", "graveyard", "bricket", "onlay", "coarser", "lioe", "hoozdoo", "gonernador", "bathous", "anzutreten", "apirl", "puzzled", "60someth", "asin", "maylani", "painkil", "shunner", "emoish", "reibungslo", "ablaufschwierigkeiten", "arahnd", "azzurro", "burson", "latvia", "conferencia", "talc", "moday", "my83", "kortesi", "crancki", "erfrischung", "misatak", "ieat", "toughest", "nostlag", "hochwertigsten", "colcchicio", "hohoto", "ek4bls5zjkx8ztwzwsin2g", "heiro", "unico", "priceless", "mikhani", "5servic", "urinal", "upromis", "koftachalow", "persev", "tolit", "smal", "yokohoma", "soulaki", "acohol", "staerkel", "smelllllllllllllllllll", "crypto", "everysandwhich", "juteus", "gelaufen", "myself1", "spittind", "leonhardskirch", "hybern", "weakquila", "songrit", "schwarzgrauen", "northern", "ohi", "mishap", "takemura", "openingggggggg", "avlyn", "funbox", "stifl", "agnol", "alibondiga", "muffalletta", "llchen", "gvfhiudm1qu2dkxh3xxtsa", "ommiss", "edinburh", "wussiest", "shiznitz", "lch", "raaaiiiiddeeerrssss", "echtholztisch", "shotszilla", "hakka", "t28", "bestcar", "jermain", "staaank", "ceri", "hanaya", "multipurpos", "nutritiou", "304", "netgearusb", "irredeem", "vibratiton", "12", "zhau", "fanatsi", "kamelien", "yiou", "3000", "comediansincarsgettingcoffe", "frasca", "redommend", "benedict", "originalen", "alleck", "cbac", "calori", "rubbermaid", "wech", "regenesi", "monial", "monkeybar", "ruft", "ender", "futukaki", "assen", "pokalfinalspiel", "sloowww", "gurgl", "hunnika", "goudazetti", "chunka", "rouch", "mclato12", "backar", "kompliment", "soondobu", "choux", "aglow", "figazia", "like", "000 ...

# %%
from IPython.display import Image
Image(filename='newplot.png')
