# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

import nltk
import string
import numpy as np
import pandas as pd
from nltk.corpus import stopwords

from sklearn.manifold import TSNE

import re
import string
from nltk.stem.wordnet import WordNetLemmatizer
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Part 3

# %% [markdown]
# ##### ---> CNN+LSTM w/ GloVe embeddings

# %%
df = pd.read_csv('new_yelp.csv', index_col=0, low_memory=False)

# %%
df.head()
# Out:
#                       review_id                 user_id  \
# 3343256  zthVOctc7sTONdtEjoi6Vg  tqxTc21Df_qLSmSbZk447g
# 3160600  tmOC1c0laXLdTwRk7Ik3lg  qszR--MaJ_qWUt-laMXFBw
# 2541439  cN444GYzJd7k52x8xUHzUw  rt3PC7WCgCKsoufmQJELfw
# 3356848  5w3kt0iaS5ifweyE0sYFhw  XlgzY-TioqNy--pxPBoH4Q
# 1215656  3ZkPcaRfX3jp7IRgtmwlqg  oN4Dq_aZuOkapFgjrVVK_w
#
#                     business_id  stars        date  \
# 3343256  59OgPGGzKFYqwSG_U06kuA      5  2015-03-23
# 3160600  U4OLUFb9VxMmpMXm1ZF-cQ      4  2012-05-08
# 2541439  g8OnV26ywJlZpezdBnOWUQ      4  2009-09-10
# 3356848  5DDumAHRKumv3gZiPKW6iw      5  2012-05-20
# 1215656  EgRpbUZKPiotTXdrOM06VA      4  2012-09-23
#
#                                                       text  useful  funny  \
# 3343256  This is my favorite Korean restaurant in Arizo...     3.0    0.0
# 3160600  I come in here every week for some delicious c...     0.0    0.0
# 2541439  We joined our out-of-town guests for breakfast...    11.0    5.0
# 3356848  First of all, the people who work here are gre...     0.0    0.0
# 1215656  What a fantastic find! We came here based on t...     0.0    0.0
#
#          cool  labels
# 3343256   0.0     1.0
# 3160600   0.0     1.0
# 2541439   8.0     1.0
# 3356848   2.0     1.0
# 1215656   0.0     1.0

# %%
df = df[~df.isna().any(axis=1)]

# %%
def clean_text(text):
    text = text.translate(string.punctuation)
    text = text.lower().split()
    stops = set(stopwords.words('english'))
    text = [word for word in text if (word not in stops) & (len(word) > 3)]
    text = ' '.join(text)
    
    #Cleaning
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)    
    
    text = text.split()
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(word) for word in text]
    text = ' '.join(lemmas)
    
    return text

# %%
df['text'] = df['text'].apply(lambda x: clean_text(x))

# %%
emb_idx = dict()
with open('glove.6B\glove.6B.100d.txt', 'r', encoding='utf-8') as file:
    for line in file:
        values = line.split()
        word = values[0]
        vec = np.asarray(values[1:], dtype='float32')
        emb_idx[word] = vec

# %%
voc_size = 20000
tokenizer = Tokenizer(num_words=voc_size)
tokenizer.fit_on_texts(df['text'])

# %%
from collections import OrderedDict
tokens = OrderedDict(sorted(tokenizer.word_index.items(), key=lambda t: t[1]))

# %%
emb_matrix = np.zeros((voc_size, 100))
for word, index in tokens.items():
    if index > (voc_size-1):
        pass
    else:
        emb_vec = emb_idx.get(word)
        if emb_vec is not None:
            emb_matrix[index] = emb_vec

# %%
seqs = tokenizer.texts_to_sequences(df['text'])
data = pad_sequences(seqs, maxlen=50)

# %%
# %%time
model = Sequential()
model.add(Embedding(voc_size, 100, input_length=50,
                   weights=[emb_matrix], trainable=True))
model.add(Dropout(.2))
model.add(Conv1D(64, 5, activation='relu'))
model.add(MaxPooling1D(pool_size=4))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', 
             metrics=['accuracy'])
model.fit(data, df['labels'], validation_split=.4, epochs=3)
# Out:
# Train on 1041810 samples, validate on 694540 samples
# Epoch 1/3
# 1041810/1041810 [==============================] - 2182s 2ms/step - loss: 0.2841 - acc: 0.8783 - val_loss: 0.2632 - val_acc: 0.8885
# Epoch 2/3
# 1041810/1041810 [==============================] - 2261s 2ms/step - loss: 0.2525 - acc: 0.8936 - val_loss: 0.2589 - val_acc: 0.8914
# Epoch 3/3
# 1041810/1041810 [==============================] - 2245s 2ms/step - loss: 0.2389 - acc: 0.9004 - val_loss: 0.2571 - val_acc: 0.8927
# Wall time: 1h 51min 29s

# %%
word_embs = model.layers[0].get_weights()[0]

# %%
X_embedded = TSNE(n_components=2, random_state=42).fit_transform(word_embs)

# %%
word_list = []
for word, i in tokens.items():
    word_list.append(word)

# %%
number_of_words = 1000
trace = go.Scatter(
    x=X_embedded[0:number_of_words,0], 
    y=X_embedded[0:number_of_words, 1],
    mode='markers',
    text=word_list[0:number_of_words]
)
layout = dict(title='t-SNE 1 vs t-SNE 2 for first 1000 words ',
              yaxis=dict(title='t-SNE 2'),
              xaxis=dict(title='t-SNE 1'),
              hovermode='closest')
fig = dict(data=[trace], layout=layout)
py.iplot(fig)
# Out:
# <div id="f3a34451-bdbc-4815-8f16-c1b6f98b08e9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f3a34451-bdbc-4815-8f16-c1b6f98b08e9", [{"x": [-12.763949394226074, 18.733173370361328, -4.68673849105835, 30.053722381591797, 29.96963119506836, 11.226903915405273, 4.7676897048950195, -14.514893531799316, 5.420932769775391, 4.634388446807861, 6.326614856719971, 3.285696506500244, 19.461997985839844, 8.404471397399902, 4.030655860900879, -4.208017826080322, 30.039745330810547, -3.318795680999756, 20.130708694458008, 34.77960205078125, 6.24152135848999, -2.2961556911468506, 30.835161209106445, -2.142522096633911, 11.317007064819336, 21.784236907958984, -11.503143310546875, 15.210550308227539, -15.5797700881958, 15.72607421875, 23.229700088500977, -9.120272636413574, 11.359794616699219, 5.286831378936768, 1.9087743759155273, 3.5574638843536377, 3.8835723400115967, -30.857254028320312, 28.895856857299805, 9.80249309539795, -27.65341567993164, -36.075592041015625, 2.749824285507202, 3.0510363578796387, 4.670